# %%
# required imports:
import os
import glob
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import precision_score, recall_score

# %%
def load_data():
    
    all_files = []
    
    for file in glob.glob("data/*.csv"):     
        df = pd.read_csv(file, on_bad_lines="skip", engine="python")
        df = df.dropna(subset=["Text"])
        lbl = file.split("/")[-1].replace(".csv", "")
        df["label"] = lbl
  
        all_files.append(df[["Text", "label"]])
    return pd.concat(all_files, ignore_index=True)

# %%
def main():
    
    df = load_data()

   
    print("Number of classes:", df["label"].nunique())
    print("Total number of samples in dataframe:", len(df))

    
    X = df["Text"].astype(str)
    y = df["label"].astype(str)

    # applying train test split
    X_train, X_values, y_train, y_values = train_test_split(X,y,test_size=0.3,random_state=40,stratify=y )


    vectorize = TfidfVectorizer()
    X_train = vectorize.fit_transform(X_train)
    X_values2 = vectorize.transform(X_values)


    model = LinearSVC()

    model.fit(X_train, y_train)
    predictions = model.predict(X_values2)
    accuracy = accuracy_score(y_values, predictions)
    # average= "macro" because there are many classes where emojis may vary in balance. 
    f1_sc = f1_score(y_values, predictions, average= "macro")

    
    print("Classification by emoji:\n")
    print(classification_report(y_values, predictions))
    print("\nSVM Accuracy:", accuracy)
    print("\nSVM Macro f1 Score", f1_sc)



    labels = sorted(df["label"].unique())

    prec = precision_score(y_values, predictions, average=None, labels=labels)
    rec = recall_score(y_values, predictions, average=None, labels=labels)


    print("labels:", labels[:10] , "and more...")
    print("Precisions:", prec[:10] , "and more...")
    print("Recalls:", rec[:10] , "and more...")
    return df, y_values, predictions

    

    

main()
# Out:
# Number of classes: 43
# Total number of samples in dataframe: 860028
# Classification by emoji:
#
#                                precision    recall  f1-score   support
#
# backhand_index_pointing_right       0.32      0.59      0.42      6008
#                    check_mark       0.38      0.42      0.40      6000
#             check_mark_button       0.37      0.43      0.40      6000
#                    clown_face       0.28      0.31      0.29      6000
#                       cooking       0.44      0.41      0.43      6000
#                           egg       0.34      0.40      0.37      6000
#                  enraged_face       0.21      0.25      0.23      6000
#                          eyes       0.17      0.15      0.16      6000
#       face_holding_back_tears       0.16      0.18      0.17      6000
#            face_savoring_food       0.30      0.31      0.31      6000
#     face_with_steam_from_nose       0.13      0.10      0.11      6000
#        face_with_tears_of_joy       0.25      0.24      0.24      6000
#                  fearful_face       0.17      0.24      0.20      6000
#                          fire       0.25      0.23      0.24      6000
#                  folded_hands       0.24      0.28      0.26      6000
#                         ghost       0.38      0.28      0.32      6000
#      grinning_face_with_sweat       0.19      0.14      0.16      6000
#                hatching_chick       0.28      0.41      0.33      6000
#                      hot_face       0.28      0.28      0.28      6000
#            loudly_crying_face       0.19      0.22      0.21      6000
#                  melting_face       0.11      0.09      0.10      6000
#                 middle_finger       0.26      0.33      0.29      6000
#                  party_popper       0.37      0.40      0.39      6000
#                 partying_face       0.30      0.26      0.28      6000
#                   pile_of_poo       0.28      0.40      0.33      6000
#                        rabbit       0.28      0.24      0.26      6000
#                   rabbit_face       0.26      0.20      0.23      6000
#                     red_heart       0.19      0.13      0.15      6001
# rolling_on_the_floor_laughing       0.17      0.13      0.15      6000
#                 saluting_face       0.19      0.16      0.17      6000
#                         skull       0.20      0.22      0.21      6000
#                  smiling_face       0.18      0.15      0.17      6000
#        smiling_face_with_halo       0.22      0.15      0.18      6000
#  smiling_face_with_heart-eyes       0.18      0.16      0.17      6000
#      smiling_face_with_hearts       0.13      0.09      0.11      6000
#  smiling_face_with_sunglasses       0.16      0.11      0.13      6000
#        smiling_face_with_tear       0.12      0.12      0.12      6000
#                      sparkles       0.17      0.10      0.13      6000
#                           sun       0.38      0.51      0.44      6000
#                 thinking_face       0.18      0.23      0.20      6000
#                     thumbs_up       0.20      0.20      0.20      6000
#                   white_heart       0.26      0.21      0.23      6000
#                  winking_face       0.16      0.11      0.13      6000
#
#                      accuracy                           0.25    258009
#                     macro avg       0.24      0.25      0.24    258009
#                  weighted avg       0.24      0.25      0.24    258009
#
#
# SVM Accuracy: 0.24630923727466872
#
# SVM Macro f1 Score 0.23893551680074984
# labels: ['backhand_index_pointing_right', 'check_mark', 'check_mark_button', 'clown_face', 'cooking', 'egg', 'enraged_face', 'eyes', 'face_holding_back_tears', 'face_savoring_food'] and more...
# Precisions: [0.32126903 0.37943368 0.37439578 0.27505112 0.44460329 0.34168791
#  0.2116349  0.17497556 0.16294643 0.30009665] and more...
# Recalls: [0.58655126 0.42433333 0.426      0.31383333 0.41466667 0.40216667
#  0.24616667 0.14916667 0.1825     0.3105    ] and more...
# (                                                     Text  \
#  0       @Erdayastronaut I hope that in reality they wi...
#  1       Exotic smoke 🌿with the sun roof down type of d...
#  2       Sky is clear sunny in Dallas, Tx what a Beauti...
#  3       @catfishparty @rottewange I WAS TRYING TO BE S...
#  4       @JUNlPER i don't even know what a circle tweet...
#  ...                                                   ...
#  860023  @rorydt22 @BreakingPoint30 @DogOfCitrus @Local...
#  860024  @parkjiminschick Usnei Rokha aur poocha  ‘can ...
#  860025  @KennyAliveAgain 😂😂 i think that’s why i gave ...
#  860026  On a scale of 1-10 how cool was Seve? 😎 https:...
#  860027               Wow! That's the coolest 😎!\n#Amazing
#
#                                 label
#  0                                sun
#  1                                sun
#  2                                sun
#  3                                sun
#  4                                sun
#  ...                              ...
#  860023  smiling_face_with_sunglasses
#  860024  smiling_face_with_sunglasses
#  860025  smiling_face_with_sunglasses
#  860026  smiling_face_with_sunglasses
#  860027  smiling_face_with_sunglasses
#
#  [860028 rows x 2 columns],
#  697682         saluting_face
#  557954          enraged_face
#  198685              sparkles
#  488282             red_heart
#  701342        hatching_chick
#                   ...
#  269342          party_popper
#  741109    loudly_crying_face
#  204254                 skull
#  736665    face_savoring_food
#  211929                 skull
#  Name: label, Length: 258009, dtype: object,
#  array(['thumbs_up', 'pile_of_poo', 'melting_face', ..., 'saluting_face',
#         'rolling_on_the_floor_laughing', 'rolling_on_the_floor_laughing'],
#        shape=(258009,), dtype=object))
